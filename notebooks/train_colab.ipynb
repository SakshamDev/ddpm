# %% [markdown]
# # DDPM Training — Colab Bootstrap
#
# This notebook is a **thin shell only**. All logic lives in the `ddpm/` package.
#
# **Workflow:** Run all cells top-to-bottom. The training loop auto-resumes from
# the latest checkpoint on Google Drive.
#
# **Never edit code in this notebook.** Push changes from your MacBook via GitHub.

# %% [markdown]
# ## Cell 1 — Verify GPU

# %%
# !nvidia-smi
import torch
print(f"\nPyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_mem / 1e9:.1f} GB")

# %% [markdown]
# ## Cell 2 — Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# Create checkpoint directory if it doesn't exist
import os
CHECKPOINT_DIR = '/content/drive/MyDrive/ddpm_checkpoints'
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
print(f"Checkpoint dir: {CHECKPOINT_DIR}")
print(f"Existing checkpoints: {os.listdir(CHECKPOINT_DIR)}")

# %% [markdown]
# ## Cell 3 — Clone or Pull Repository
#
# ⚠️ **Set your GitHub repo URL below before first run.**

# %%
import os

# ===== SET YOUR REPO URL HERE =====
REPO_URL = 'https://github.com/YOUR_USERNAME/DDPM.git'  # <-- CHANGE THIS
REPO_DIR = '/content/DDPM'
# ==================================

if os.path.isdir(REPO_DIR):
    print('Repo exists — pulling latest changes...')
    # !cd {REPO_DIR} && git pull
else:
    print('Cloning repo...')
    # !git clone {REPO_URL} {REPO_DIR}

os.chdir(REPO_DIR)
# !git log --oneline -3

# %% [markdown]
# ## Cell 4 — Install Dependencies

# %%
# !pip install -e . -q

# %% [markdown]
# ## Cell 5 — Verify Setup

# %%
from ddpm.config import DDPMConfig
from ddpm.utils import get_device, get_git_commit
from ddpm.checkpoint import find_latest_checkpoint

config = DDPMConfig()
device = get_device()
commit = get_git_commit()
latest = find_latest_checkpoint(config.checkpoint_dir)

print(f"Device: {device}")
print(f"Git commit: {commit}")
print(f"Config: {config.summary()}")
print(f"Latest checkpoint: {latest or 'None (starting fresh)'}")

# %% [markdown]
# ## Cell 6 — Train
#
# This cell calls the training entry point, which auto-resumes if a checkpoint exists.
#
# **Not yet implemented** — will be added in Milestone 4.

# %%
# from ddpm.train import main
# main()  # Auto-resumes from latest checkpoint
print('Training entry point not yet implemented. Coming in Milestone 4.')
